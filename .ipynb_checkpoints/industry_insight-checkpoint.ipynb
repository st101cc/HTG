# %%
import pandas as pd

# %%
#read in the table that contains data about business confidence level in difference manufacturing sectors 
df_wide = pd.read_excel('data/Manufacturing.xlsx')
df_wide = df_wide.drop(columns='Feb-22')
df_wide = df_wide.drop([0])
df_wide
# Out:
#                                    INDUSTRIAL SECTORS  Jan-23  Feb-23
# 1                                                Food    50.8    51.5
# 2                                           Beverages    51.7    51.0
# 3                                            Textiles    48.6    51.1
# 4      Manufacture of wearing apparel and accessories    48.5    46.4
# 5                                             Leather    50.4    48.7
# 6                                  Footwear and parts    51.0    51.0
# 7                                                Wood    44.7    43.3
# 8                                      Pulp and paper    48.1    50.6
# 9             Printing and reproduction of recordings    48.9    50.4
# 10                                           Biofuels    46.6    49.5
# 11                            Chemicals (Except HPPC)    48.1    51.6
# 12  Cleaning products, perfumes and personal hygie...    51.6    57.1
# 13                Pharmochemicals and pharmaceuticals    54.8    60.4
# 14                                             Rubber    46.8    49.5
# 15                                   Plastic products    44.5    47.4
# 16                               Non-metallic mineral    45.4    45.0
# 17                                       Basic metals    49.6    52.6
# 18    Metal products (except machinery and equipment)    49.2    51.1
# 19                  Computers, electronics and others    43.3    48.4
# 20      Electrical machinery, equipment and materials    48.1    53.5
# 21                            Machinery and equipment    44.8    49.2
# 22              Motor vehicles, trailers and bodywork    49.1    53.2
# 23                                          Furniture    46.5    47.0
# 24                                Other manufacturing    51.5    51.6
# 25  Repair and installation of machinery and equip...    53.4    52.3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#plot the data recorded at January 2023 in bar charts, where the brown columns represent sectors that businesses have relatively low confidence in
cols = ['brown' if x < 50 else 'orange' for x in df_wide['Jan-23']]

fig, ax = plt.subplots(figsize=(16,5))
sns.barplot(data=df_wide, x='INDUSTRIAL SECTORS', y='Jan-23', palette=cols)
plt.xticks(rotation=90)
plt.xlabel('Industrial sectors')
plt.ylabel('Business confidence index')
plt.title('Business confidence index for manufacturing industrial sectors in Brazil at Jan-23')
# Out:
# Text(0.5, 1.0, 'Business confidence index for manufacturing industrial sectors in Brazil at Jan-23')

# %%
#plot the data recorded at February 2023 in bar charts, where the brown columns represent sectors that businesses have relatively low confidence in
cols = ['brown' if x < 50 else 'orange' for x in df_wide['Feb-23']]

fig, ax = plt.subplots(figsize=(16,5))
sns.barplot(data=df_wide, x='INDUSTRIAL SECTORS', y='Feb-23', palette=cols)
plt.xticks(rotation=90)
plt.xlabel('Industrial sectors')
plt.ylabel('Business confidence index')
plt.title('Business confidence index for manufacturing industrial sectors in Brazil at Feb-23')
# Out:
# Text(0.5, 1.0, 'Business confidence index for manufacturing industrial sectors in Brazil at Feb-23')

# %%
#transform data from wide form to long form for ease of plotting
df_long = pd.melt(df_wide, id_vars='INDUSTRIAL SECTORS', value_vars=['Jan-23', 'Feb-23'])
df_long
# Out:
#                                    INDUSTRIAL SECTORS variable  value
# 0                                                Food   Jan-23   50.8
# 1                                           Beverages   Jan-23   51.7
# 2                                            Textiles   Jan-23   48.6
# 3      Manufacture of wearing apparel and accessories   Jan-23   48.5
# 4                                             Leather   Jan-23   50.4
# 5                                  Footwear and parts   Jan-23   51.0
# 6                                                Wood   Jan-23   44.7
# 7                                      Pulp and paper   Jan-23   48.1
# 8             Printing and reproduction of recordings   Jan-23   48.9
# 9                                            Biofuels   Jan-23   46.6
# 10                            Chemicals (Except HPPC)   Jan-23   48.1
# 11  Cleaning products, perfumes and personal hygie...   Jan-23   51.6
# 12                Pharmochemicals and pharmaceuticals   Jan-23   54.8
# 13                                             Rubber   Jan-23   46.8
# 14                                   Plastic products   Jan-23   44.5
# 15                               Non-metallic mineral   Jan-23   45.4
# 16                                       Basic metals   Jan-23   49.6
# 17    Metal products (except machinery and equipment)   Jan-23   49.2
# 18                  Computers, electronics and others   Jan-23   43.3
# 19      Electrical machinery, equipment and materials   Jan-23   48.1
# 20                            Machinery and equipment   Jan-23   44.8
# 21              Motor vehicles, trailers and bodywork   Jan-23   49.1
# 22                                          Furniture   Jan-23   46.5
# 23                                Other manufacturing   Jan-23   51.5
# 24  Repair and installation of machinery and equip...   Jan-23   53.4
# 25                                               Food   Feb-23   51.5
# 26                                          Beverages   Feb-23   51.0
# 27                                           Textiles   Feb-23   51.1
# 28     Manufacture of wearing apparel and accessories   Feb-23   46.4
# 29                                            Leather   Feb-23   48.7
# 30                                 Footwear and parts   Feb-23   51.0
# 31                                               Wood   Feb-23   43.3
# 32                                     Pulp and paper   Feb-23   50.6
# 33            Printing and reproduction of recordings   Feb-23   50.4
# 34                                           Biofuels   Feb-23   49.5
# 35                            Chemicals (Except HPPC)   Feb-23   51.6
# 36  Cleaning products, perfumes and personal hygie...   Feb-23   57.1
# 37                Pharmochemicals and pharmaceuticals   Feb-23   60.4
# 38                                             Rubber   Feb-23   49.5
# 39                                   Plastic products   Feb-23   47.4
# 40                               Non-metallic mineral   Feb-23   45.0
# 41                                       Basic metals   Feb-23   52.6
# 42    Metal products (except machinery and equipment)   Feb-23   51.1
# 43                  Computers, electronics and others   Feb-23   48.4
# 44      Electrical machinery, equipment and materials   Feb-23   53.5
# 45                            Machinery and equipment   Feb-23   49.2
# 46              Motor vehicles, trailers and bodywork   Feb-23   53.2
# 47                                          Furniture   Feb-23   47.0
# 48                                Other manufacturing   Feb-23   51.6
# 49  Repair and installation of machinery and equip...   Feb-23   52.3

# %%
#plot the data recorded at January and February 2023 in side by side bar charts to see the difference in confidence index for each sectors
fig, ax = plt.subplots(figsize=(20,8))
sns.barplot(data=df_long, x='INDUSTRIAL SECTORS', y='value', hue='variable')
plt.xticks(rotation=90)
plt.xlabel('Industrial sectors')
plt.ylabel('Business confidence index')
plt.title('Business confidence index for manufacturing industrial sectors in Brazil')
# Out:
# Text(0.5, 1.0, 'Business confidence index for manufacturing industrial sectors in Brazil')
